# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import linregress
from scipy.stats import linregress
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
from citipy import citipy
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d38196a199a8a0ee781a866d25d0ca4a

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for lat_lngs in lat_lngs:
    city = citipy.nearest_city(lat_lngs[0], lat_lngs[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 736

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Make an API request for each city 
    try:
       
        # Parse the JSON data
        city_weather = requests.get(city_url).json()
        
        # Parse the JSON and retrieve data.
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']
        
        # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | alekseyevsk
# Processing Record 3 of Set 1 | hilo
# Processing Record 4 of Set 1 | dikson
# Processing Record 5 of Set 1 | saldanha
# Processing Record 6 of Set 1 | cabo san lucas
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | tilichiki
# Processing Record 10 of Set 1 | kahului
# Processing Record 11 of Set 1 | sao miguel do araguaia
# Processing Record 12 of Set 1 | camocim
# Processing Record 13 of Set 1 | kostomuksha
# Processing Record 14 of Set 1 | quesnel
# Processing Record 15 of Set 1 | butaritari
# Processing Record 16 of Set 1 | prince rupert
# Processing Record 17 of Set 1 | new norfolk
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | tambura
# Processing Record 20 of Set 1 | nurota
# Processing Record 21 of Set 1 | karlstad
# Processing Record 22 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | gurupi
# Processing Record 25 of Set 1 | bredasdorp
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | talcahuano
# Processing Record 28 of Set 1 | mumford
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | beringovskiy
# Processing Record 31 of Set 1 | nanortalik
# Processing Record 32 of Set 1 | anloga
# Processing Record 33 of Set 1 | barrow
# Processing Record 34 of Set 1 | takab
# Processing Record 35 of Set 1 | luderitz
# Processing Record 36 of Set 1 | saint-philippe
# Processing Record 37 of Set 1 | conde
# Processing Record 38 of Set 1 | thompson
# Processing Record 39 of Set 1 | saskylakh
# Processing Record 40 of Set 1 | chokurdakh
# Processing Record 41 of Set 1 | turbana
# Processing Record 42 of Set 1 | mayskiy
# Processing Record 43 of Set 1 | tasiilaq
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | ponta do sol
# Processing Record 46 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 1 | praia da vitoria
# Processing Record 48 of Set 1 | flinders
# Processing Record 49 of Set 1 | scarborough
# Processing Record 50 of Set 1 | parchim
# Processing Record 1 of Set 2 | dunedin
# Processing Record 2 of Set 2 | castro
# Processing Record 3 of Set 2 | atar
# Processing Record 4 of Set 2 | qaanaaq
# Processing Record 5 of Set 2 | port lincoln
# Processing Record 6 of Set 2 | omboue
# Processing Record 7 of Set 2 | vestmannaeyjar
# Processing Record 8 of Set 2 | nikolskoye
# Processing Record 9 of Set 2 | busselton
# Processing Record 10 of Set 2 | hobart
# Processing Record 11 of Set 2 | stornoway
# Processing Record 12 of Set 2 | henties bay
# Processing Record 13 of Set 2 | buariki
# City not found. Skipping...
# Processing Record 14 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 2 | karamay
# City not found. Skipping...
# Processing Record 16 of Set 2 | kyshtovka
# Processing Record 17 of Set 2 | arroyo
# Processing Record 18 of Set 2 | vaini
# Processing Record 19 of Set 2 | sao filipe
# Processing Record 20 of Set 2 | yellowknife
# Processing Record 21 of Set 2 | kruisfontein
# Processing Record 22 of Set 2 | coquimbo
# Processing Record 23 of Set 2 | clonmel
# Processing Record 24 of Set 2 | mamallapuram
# Processing Record 25 of Set 2 | albany
# Processing Record 26 of Set 2 | horodnytsya
# Processing Record 27 of Set 2 | khatanga
# Processing Record 28 of Set 2 | atuona
# Processing Record 29 of Set 2 | avarua
# Processing Record 30 of Set 2 | tiksi
# Processing Record 31 of Set 2 | norman wells
# Processing Record 32 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 2 | laguna
# Processing Record 34 of Set 2 | addi ugri
# City not found. Skipping...
# Processing Record 35 of Set 2 | puerto carreno
# Processing Record 36 of Set 2 | kavieng
# Processing Record 37 of Set 2 | marawi
# Processing Record 38 of Set 2 | atbasar
# Processing Record 39 of Set 2 | jalu
# Processing Record 40 of Set 2 | chuy
# Processing Record 41 of Set 2 | singapore
# Processing Record 42 of Set 2 | arraial do cabo
# Processing Record 43 of Set 2 | san cristobal
# Processing Record 44 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 45 of Set 2 | islahiye
# Processing Record 46 of Set 2 | meulaboh
# Processing Record 47 of Set 2 | dawson creek
# Processing Record 48 of Set 2 | hithadhoo
# Processing Record 49 of Set 2 | diamantino
# Processing Record 50 of Set 2 | pemberton
# Processing Record 1 of Set 3 | sitka
# Processing Record 2 of Set 3 | cherskiy
# Processing Record 3 of Set 3 | dalbandin
# Processing Record 4 of Set 3 | vardo
# Processing Record 5 of Set 3 | carnduff
# Processing Record 6 of Set 3 | svetlyy
# Processing Record 7 of Set 3 | gorom-gorom
# Processing Record 8 of Set 3 | port elizabeth
# Processing Record 9 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 10 of Set 3 | geraldton
# Processing Record 11 of Set 3 | hereford
# Processing Record 12 of Set 3 | bondo
# Processing Record 13 of Set 3 | uvat
# Processing Record 14 of Set 3 | warrnambool
# Processing Record 15 of Set 3 | ejido hermosillo
# Processing Record 16 of Set 3 | west wendover
# Processing Record 17 of Set 3 | havoysund
# Processing Record 18 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 3 | zhigansk
# Processing Record 20 of Set 3 | nelson bay
# Processing Record 21 of Set 3 | sabha
# Processing Record 22 of Set 3 | tuktoyaktuk
# Processing Record 23 of Set 3 | faanui
# Processing Record 24 of Set 3 | shebalino
# Processing Record 25 of Set 3 | isangel
# Processing Record 26 of Set 3 | port hedland
# Processing Record 27 of Set 3 | ellisras
# Processing Record 28 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 3 | bell ville
# Processing Record 30 of Set 3 | brigantine
# Processing Record 31 of Set 3 | comodoro rivadavia
# Processing Record 32 of Set 3 | wattegama
# Processing Record 33 of Set 3 | porto novo
# Processing Record 34 of Set 3 | aklavik
# Processing Record 35 of Set 3 | okhotsk
# Processing Record 36 of Set 3 | sioux lookout
# Processing Record 37 of Set 3 | nieuwpoort
# Processing Record 38 of Set 3 | goba
# Processing Record 39 of Set 3 | longyearbyen
# Processing Record 40 of Set 3 | acapulco
# Processing Record 41 of Set 3 | kupang
# Processing Record 42 of Set 3 | verkhoyansk
# Processing Record 43 of Set 3 | aransas pass
# Processing Record 44 of Set 3 | gimbi
# Processing Record 45 of Set 3 | broken hill
# Processing Record 46 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 3 | hermanus
# Processing Record 48 of Set 3 | suclayin
# Processing Record 49 of Set 3 | mulege
# Processing Record 50 of Set 3 | palembang
# Processing Record 1 of Set 4 | negru voda
# Processing Record 2 of Set 4 | avera
# Processing Record 3 of Set 4 | torbay
# Processing Record 4 of Set 4 | tokur
# Processing Record 5 of Set 4 | hambantota
# Processing Record 6 of Set 4 | lebu
# Processing Record 7 of Set 4 | acarau
# Processing Record 8 of Set 4 | ahipara
# Processing Record 9 of Set 4 | puerto ayora
# Processing Record 10 of Set 4 | iqaluit
# Processing Record 11 of Set 4 | provideniya
# Processing Record 12 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 4 | baykit
# Processing Record 14 of Set 4 | high rock
# Processing Record 15 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 4 | falam
# Processing Record 17 of Set 4 | beloha
# Processing Record 18 of Set 4 | mahebourg
# Processing Record 19 of Set 4 | airai
# Processing Record 20 of Set 4 | bethel
# Processing Record 21 of Set 4 | pangnirtung
# Processing Record 22 of Set 4 | post falls
# Processing Record 23 of Set 4 | necochea
# Processing Record 24 of Set 4 | maceio
# Processing Record 25 of Set 4 | georgetown
# Processing Record 26 of Set 4 | homer
# Processing Record 27 of Set 4 | nhulunbuy
# Processing Record 28 of Set 4 | porbandar
# Processing Record 29 of Set 4 | grindavik
# Processing Record 30 of Set 4 | srednekolymsk
# Processing Record 31 of Set 4 | tiznit
# Processing Record 32 of Set 4 | oranjemund
# Processing Record 33 of Set 4 | sao joao da barra
# Processing Record 34 of Set 4 | bambous virieux
# Processing Record 35 of Set 4 | pangody
# Processing Record 36 of Set 4 | bria
# Processing Record 37 of Set 4 | kununurra
# Processing Record 38 of Set 4 | alexandria
# Processing Record 39 of Set 4 | havre-saint-pierre
# Processing Record 40 of Set 4 | fortuna
# Processing Record 41 of Set 4 | shubarkuduk
# Processing Record 42 of Set 4 | ilulissat
# Processing Record 43 of Set 4 | college
# Processing Record 44 of Set 4 | brae
# Processing Record 45 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 4 | san quintin
# Processing Record 47 of Set 4 | east london
# Processing Record 48 of Set 4 | gizo
# Processing Record 49 of Set 4 | yulara
# Processing Record 50 of Set 4 | kapaa
# Processing Record 1 of Set 5 | saint george
# Processing Record 2 of Set 5 | ayan
# Processing Record 3 of Set 5 | clyde river
# Processing Record 4 of Set 5 | aguimes
# Processing Record 5 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 5 | talnakh
# Processing Record 7 of Set 5 | kodiak
# Processing Record 8 of Set 5 | merauke
# Processing Record 9 of Set 5 | dingle
# Processing Record 10 of Set 5 | liverpool
# Processing Record 11 of Set 5 | laredo
# Processing Record 12 of Set 5 | marica
# Processing Record 13 of Set 5 | bardiyah
# Processing Record 14 of Set 5 | bathsheba
# Processing Record 15 of Set 5 | mar del plata
# Processing Record 16 of Set 5 | upernavik
# Processing Record 17 of Set 5 | cidreira
# Processing Record 18 of Set 5 | tengzhou
# Processing Record 19 of Set 5 | rock springs
# Processing Record 20 of Set 5 | redmond
# Processing Record 21 of Set 5 | lagoa
# Processing Record 22 of Set 5 | olga
# Processing Record 23 of Set 5 | nagapattinam
# Processing Record 24 of Set 5 | salalah
# Processing Record 25 of Set 5 | wagga wagga
# Processing Record 26 of Set 5 | negele
# City not found. Skipping...
# Processing Record 27 of Set 5 | zhanaozen
# Processing Record 28 of Set 5 | matara
# Processing Record 29 of Set 5 | kortkeros
# Processing Record 30 of Set 5 | turukhansk
# Processing Record 31 of Set 5 | evensk
# Processing Record 32 of Set 5 | maple creek
# Processing Record 33 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 5 | lagos
# Processing Record 35 of Set 5 | grand gaube
# Processing Record 36 of Set 5 | richards bay
# Processing Record 37 of Set 5 | troitsko-pechorsk
# Processing Record 38 of Set 5 | winslow
# Processing Record 39 of Set 5 | hanzhong
# Processing Record 40 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 41 of Set 5 | faya
# Processing Record 42 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 43 of Set 5 | mus
# Processing Record 44 of Set 5 | daru
# Processing Record 45 of Set 5 | adrar
# Processing Record 46 of Set 5 | teguise
# Processing Record 47 of Set 5 | balmedie
# Processing Record 48 of Set 5 | ribeira grande
# Processing Record 49 of Set 5 | nome
# Processing Record 50 of Set 5 | irbil
# Processing Record 1 of Set 6 | katsuura
# Processing Record 2 of Set 6 | port macquarie
# Processing Record 3 of Set 6 | yerbogachen
# Processing Record 4 of Set 6 | bilma
# Processing Record 5 of Set 6 | hargeysa
# Processing Record 6 of Set 6 | pevek
# Processing Record 7 of Set 6 | basco
# Processing Record 8 of Set 6 | riyadh
# Processing Record 9 of Set 6 | vila
# Processing Record 10 of Set 6 | vila velha
# Processing Record 11 of Set 6 | dehloran
# Processing Record 12 of Set 6 | benguela
# Processing Record 13 of Set 6 | mayfield
# Processing Record 14 of Set 6 | grieskirchen
# Processing Record 15 of Set 6 | ambovombe
# Processing Record 16 of Set 6 | hasaki
# Processing Record 17 of Set 6 | touros
# Processing Record 18 of Set 6 | waipawa
# Processing Record 19 of Set 6 | fairbanks
# Processing Record 20 of Set 6 | bol
# Processing Record 21 of Set 6 | san andres
# Processing Record 22 of Set 6 | taoudenni
# Processing Record 23 of Set 6 | leningradskiy
# Processing Record 24 of Set 6 | qaqortoq
# Processing Record 25 of Set 6 | severo-kurilsk
# Processing Record 26 of Set 6 | azul
# Processing Record 27 of Set 6 | churachandpur
# Processing Record 28 of Set 6 | port alfred
# Processing Record 29 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 30 of Set 6 | haverfordwest
# Processing Record 31 of Set 6 | caravelas
# Processing Record 32 of Set 6 | portobelo
# Processing Record 33 of Set 6 | padang
# Processing Record 34 of Set 6 | bambanglipuro
# Processing Record 35 of Set 6 | ipameri
# Processing Record 36 of Set 6 | kalmunai
# Processing Record 37 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 6 | antalaha
# Processing Record 39 of Set 6 | along
# Processing Record 40 of Set 6 | alofi
# Processing Record 41 of Set 6 | esso
# Processing Record 42 of Set 6 | lata
# Processing Record 43 of Set 6 | phan thiet
# Processing Record 44 of Set 6 | eravur
# Processing Record 45 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 46 of Set 6 | saint-pierre
# Processing Record 47 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 6 | tarut
# Processing Record 49 of Set 6 | ravar
# Processing Record 50 of Set 6 | gotsu
# Processing Record 1 of Set 7 | kholodnyy
# Processing Record 2 of Set 7 | makakilo city
# Processing Record 3 of Set 7 | luhyny
# Processing Record 4 of Set 7 | husavik
# Processing Record 5 of Set 7 | luwuk
# Processing Record 6 of Set 7 | oskarshamn
# Processing Record 7 of Set 7 | lompoc
# Processing Record 8 of Set 7 | nam tha
# City not found. Skipping...
# Processing Record 9 of Set 7 | aswan
# Processing Record 10 of Set 7 | saint-augustin
# Processing Record 11 of Set 7 | miraflores
# Processing Record 12 of Set 7 | bengkulu
# Processing Record 13 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 7 | kirkuk
# Processing Record 15 of Set 7 | nueva gerona
# Processing Record 16 of Set 7 | sorland
# Processing Record 17 of Set 7 | victoria
# Processing Record 18 of Set 7 | carnarvon
# Processing Record 19 of Set 7 | ca mau
# Processing Record 20 of Set 7 | aneho
# Processing Record 21 of Set 7 | paraiso
# Processing Record 22 of Set 7 | xining
# Processing Record 23 of Set 7 | cairns
# Processing Record 24 of Set 7 | belmonte
# Processing Record 25 of Set 7 | samarai
# Processing Record 26 of Set 7 | nuuk
# Processing Record 27 of Set 7 | sawang daen din
# Processing Record 28 of Set 7 | coahuayana
# Processing Record 29 of Set 7 | vao
# Processing Record 30 of Set 7 | trairi
# Processing Record 31 of Set 7 | hofn
# Processing Record 32 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 33 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 7 | vostok
# Processing Record 35 of Set 7 | venezuela
# Processing Record 36 of Set 7 | ugoofaaru
# Processing Record 37 of Set 7 | tomatlan
# Processing Record 38 of Set 7 | grajau
# Processing Record 39 of Set 7 | murdochville
# Processing Record 40 of Set 7 | sabang
# Processing Record 41 of Set 7 | inirida
# Processing Record 42 of Set 7 | port keats
# Processing Record 43 of Set 7 | chabahar
# Processing Record 44 of Set 7 | ponta delgada
# Processing Record 45 of Set 7 | fukuma
# Processing Record 46 of Set 7 | hovd
# Processing Record 47 of Set 7 | vikindu
# Processing Record 48 of Set 7 | george
# Processing Record 49 of Set 7 | komsomolskiy
# Processing Record 50 of Set 7 | ngunguru
# Processing Record 1 of Set 8 | ancud
# Processing Record 2 of Set 8 | filadelfia
# Processing Record 3 of Set 8 | milledgeville
# Processing Record 4 of Set 8 | karratha
# Processing Record 5 of Set 8 | xam nua
# Processing Record 6 of Set 8 | port maria
# Processing Record 7 of Set 8 | phetchabun
# Processing Record 8 of Set 8 | moindou
# Processing Record 9 of Set 8 | port blair
# Processing Record 10 of Set 8 | vavuniya
# Processing Record 11 of Set 8 | ambilobe
# Processing Record 12 of Set 8 | mount pleasant
# Processing Record 13 of Set 8 | esperance
# Processing Record 14 of Set 8 | odweyne
# Processing Record 15 of Set 8 | nishihara
# Processing Record 16 of Set 8 | lichtenburg
# Processing Record 17 of Set 8 | tuatapere
# Processing Record 18 of Set 8 | teya
# Processing Record 19 of Set 8 | aljezur
# Processing Record 20 of Set 8 | lashio
# Processing Record 21 of Set 8 | pisco
# Processing Record 22 of Set 8 | coos bay
# Processing Record 23 of Set 8 | pingxiang
# Processing Record 24 of Set 8 | eldorado
# Processing Record 25 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 8 | olinda
# Processing Record 27 of Set 8 | labuhan
# Processing Record 28 of Set 8 | machiques
# Processing Record 29 of Set 8 | pyinmana
# Processing Record 30 of Set 8 | paamiut
# Processing Record 31 of Set 8 | namibe
# Processing Record 32 of Set 8 | road town
# Processing Record 33 of Set 8 | kulhudhuffushi
# Processing Record 34 of Set 8 | barra do garcas
# Processing Record 35 of Set 8 | chadiza
# Processing Record 36 of Set 8 | hamilton
# Processing Record 37 of Set 8 | zlotoryja
# Processing Record 38 of Set 8 | kui buri
# Processing Record 39 of Set 8 | san patricio
# Processing Record 40 of Set 8 | umm lajj
# Processing Record 41 of Set 8 | camacupa
# Processing Record 42 of Set 8 | araouane
# Processing Record 43 of Set 8 | muncar
# Processing Record 44 of Set 8 | charters towers
# Processing Record 45 of Set 8 | marsh harbour
# Processing Record 46 of Set 8 | poplar bluff
# Processing Record 47 of Set 8 | bafoussam
# Processing Record 48 of Set 8 | birin
# Processing Record 49 of Set 8 | berlevag
# Processing Record 50 of Set 8 | rutana
# Processing Record 1 of Set 9 | bahia blanca
# Processing Record 2 of Set 9 | carballo
# Processing Record 3 of Set 9 | hobyo
# Processing Record 4 of Set 9 | senneterre
# Processing Record 5 of Set 9 | margate
# Processing Record 6 of Set 9 | manggar
# Processing Record 7 of Set 9 | lazaro cardenas
# Processing Record 8 of Set 9 | lorengau
# Processing Record 9 of Set 9 | porterville
# Processing Record 10 of Set 9 | tezu
# Processing Record 11 of Set 9 | rock sound
# Processing Record 12 of Set 9 | shetpe
# Processing Record 13 of Set 9 | adelaide
# Processing Record 14 of Set 9 | ulladulla
# Processing Record 15 of Set 9 | petauke
# Processing Record 16 of Set 9 | kaeo
# Processing Record 17 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 18 of Set 9 | inuvik
# Processing Record 19 of Set 9 | tazovskiy
# Processing Record 20 of Set 9 | itarema
# Processing Record 21 of Set 9 | celestun
# Processing Record 22 of Set 9 | high level
# Processing Record 23 of Set 9 | mongu
# Processing Record 24 of Set 9 | avanigadda
# Processing Record 25 of Set 9 | akonolinga
# Processing Record 26 of Set 9 | amuntai
# Processing Record 27 of Set 9 | ambon
# Processing Record 28 of Set 9 | babu
# Processing Record 29 of Set 9 | acajutla
# Processing Record 30 of Set 9 | antofagasta
# Processing Record 31 of Set 9 | charlottetown
# Processing Record 32 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 9 | pamanukan
# Processing Record 34 of Set 9 | khuzhir
# Processing Record 35 of Set 9 | svetlaya
# Processing Record 36 of Set 9 | kaitangata
# Processing Record 37 of Set 9 | sao joao dos patos
# Processing Record 38 of Set 9 | marsaxlokk
# Processing Record 39 of Set 9 | illapel
# Processing Record 40 of Set 9 | pontal do parana
# Processing Record 41 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 42 of Set 9 | tornio
# Processing Record 43 of Set 9 | mercedes
# Processing Record 44 of Set 9 | vanimo
# Processing Record 45 of Set 9 | belaya gora
# Processing Record 46 of Set 9 | zelenyy bor
# Processing Record 47 of Set 9 | los chiles
# Processing Record 48 of Set 9 | hualmay
# Processing Record 49 of Set 9 | verkhnyaya toyma
# Processing Record 50 of Set 9 | harper
# Processing Record 1 of Set 10 | chapais
# Processing Record 2 of Set 10 | hay river
# Processing Record 3 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 4 of Set 10 | kodinsk
# Processing Record 5 of Set 10 | kuching
# Processing Record 6 of Set 10 | balykshi
# Processing Record 7 of Set 10 | saint-joseph
# Processing Record 8 of Set 10 | souillac
# Processing Record 9 of Set 10 | santa cruz
# Processing Record 10 of Set 10 | zuenoula
# Processing Record 11 of Set 10 | panama city
# Processing Record 12 of Set 10 | kalakamati
# Processing Record 13 of Set 10 | buala
# Processing Record 14 of Set 10 | progreso
# Processing Record 15 of Set 10 | buin
# Processing Record 16 of Set 10 | bangassou
# Processing Record 17 of Set 10 | marzuq
# Processing Record 18 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 19 of Set 10 | eureka
# Processing Record 20 of Set 10 | dryden
# Processing Record 21 of Set 10 | dolinsk
# Processing Record 22 of Set 10 | bitung
# Processing Record 23 of Set 10 | saint anthony
# Processing Record 24 of Set 10 | kobojango
# City not found. Skipping...
# Processing Record 25 of Set 10 | umea
# Processing Record 26 of Set 10 | najran
# Processing Record 27 of Set 10 | cabedelo
# Processing Record 28 of Set 10 | coihaique
# Processing Record 29 of Set 10 | mareeba
# Processing Record 30 of Set 10 | mount gambier
# Processing Record 31 of Set 10 | birao
# Processing Record 32 of Set 10 | batemans bay
# Processing Record 33 of Set 10 | pringsewu
# Processing Record 34 of Set 10 | tura
# Processing Record 35 of Set 10 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 36 of Set 10 | suluq
# Processing Record 37 of Set 10 | petionville
# Processing Record 38 of Set 10 | san jose
# Processing Record 39 of Set 10 | balagansk
# Processing Record 40 of Set 10 | canicatti
# Processing Record 41 of Set 10 | alta floresta
# Processing Record 42 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 43 of Set 10 | nemuro
# Processing Record 44 of Set 10 | mitu
# Processing Record 45 of Set 10 | zabid
# Processing Record 46 of Set 10 | moerai
# Processing Record 47 of Set 10 | muros
# Processing Record 48 of Set 10 | haines junction
# Processing Record 49 of Set 10 | bandar
# Processing Record 50 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 11 | rawson
# Processing Record 2 of Set 11 | waddan
# Processing Record 3 of Set 11 | katha
# City not found. Skipping...
# Processing Record 4 of Set 11 | san gabriel casa blanca
# Processing Record 5 of Set 11 | macamic
# Processing Record 6 of Set 11 | cortez
# Processing Record 7 of Set 11 | isla vista
# Processing Record 8 of Set 11 | westport
# Processing Record 9 of Set 11 | galashki
# Processing Record 10 of Set 11 | swindon
# Processing Record 11 of Set 11 | alice springs
# Processing Record 12 of Set 11 | klaksvik
# Processing Record 13 of Set 11 | roald
# Processing Record 14 of Set 11 | gambiran
# Processing Record 15 of Set 11 | aioi
# Processing Record 16 of Set 11 | thano bula khan
# City not found. Skipping...
# Processing Record 17 of Set 11 | villers-les-nancy
# Processing Record 18 of Set 11 | cururupu
# Processing Record 19 of Set 11 | kenai
# Processing Record 20 of Set 11 | baillif
# Processing Record 21 of Set 11 | zaragoza
# Processing Record 22 of Set 11 | bud
# Processing Record 23 of Set 11 | nouadhibou
# Processing Record 24 of Set 11 | mahibadhoo
# Processing Record 25 of Set 11 | juneau
# Processing Record 26 of Set 11 | abu samrah
# Processing Record 27 of Set 11 | sobolevo
# Processing Record 28 of Set 11 | qasigiannguit
# Processing Record 29 of Set 11 | kariba
# Processing Record 30 of Set 11 | ishigaki
# Processing Record 31 of Set 11 | helong
# Processing Record 32 of Set 11 | osa
# Processing Record 33 of Set 11 | yar-sale
# Processing Record 34 of Set 11 | lao cai
# Processing Record 35 of Set 11 | nicoya
# Processing Record 36 of Set 11 | semey
# Processing Record 37 of Set 11 | payson
# Processing Record 38 of Set 11 | tukrah
# Processing Record 39 of Set 11 | thinadhoo
# Processing Record 40 of Set 11 | dongkan
# Processing Record 41 of Set 11 | la romana
# Processing Record 42 of Set 11 | seoul
# Processing Record 43 of Set 11 | hervey bay
# Processing Record 44 of Set 11 | broome
# Processing Record 45 of Set 11 | laramie
# Processing Record 46 of Set 11 | novobirilyussy
# Processing Record 47 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 48 of Set 11 | bilibino
# Processing Record 49 of Set 11 | asfi
# Processing Record 50 of Set 11 | colares
# Processing Record 1 of Set 12 | vila franca do campo
# Processing Record 2 of Set 12 | neuquen
# Processing Record 3 of Set 12 | tikrit
# Processing Record 4 of Set 12 | dali
# Processing Record 5 of Set 12 | alto araguaia
# Processing Record 6 of Set 12 | rodrigues alves
# Processing Record 7 of Set 12 | half moon bay
# Processing Record 8 of Set 12 | qinhuangdao
# Processing Record 9 of Set 12 | kachiry
# Processing Record 10 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 11 of Set 12 | kichmengskiy gorodok
# Processing Record 12 of Set 12 | aleksandrovskoye
# Processing Record 13 of Set 12 | almaznyy
# Processing Record 14 of Set 12 | certegui
# Processing Record 15 of Set 12 | ixtapa
# Processing Record 16 of Set 12 | santiago de cao
# Processing Record 17 of Set 12 | concarneau
# Processing Record 18 of Set 12 | oussouye
# Processing Record 19 of Set 12 | zambezi
# Processing Record 20 of Set 12 | boden
# Processing Record 21 of Set 12 | calvia
# Processing Record 22 of Set 12 | visnes
# Processing Record 23 of Set 12 | matay
# Processing Record 24 of Set 12 | pemangkat
# Processing Record 25 of Set 12 | houston
# Processing Record 26 of Set 12 | aitape
# Processing Record 27 of Set 12 | kalianget
# Processing Record 28 of Set 12 | tabou
# Processing Record 29 of Set 12 | caxito
# Processing Record 30 of Set 12 | urumqi
# Processing Record 31 of Set 12 | tanete
# Processing Record 32 of Set 12 | puerto baquerizo moreno
# Processing Record 33 of Set 12 | multan
# Processing Record 34 of Set 12 | praya
# Processing Record 35 of Set 12 | ossora
# Processing Record 36 of Set 12 | dicabisagan
# Processing Record 37 of Set 12 | graaff-reinet
# Processing Record 38 of Set 12 | caraballeda
# Processing Record 39 of Set 12 | sandavagur
# City not found. Skipping...
# Processing Record 40 of Set 12 | yuanping
# Processing Record 41 of Set 12 | soe
# Processing Record 42 of Set 12 | bayangol
# Processing Record 43 of Set 12 | adiake
# Processing Record 44 of Set 12 | coolum beach
# Processing Record 45 of Set 12 | portland
# Processing Record 46 of Set 12 | contramaestre
# Processing Record 47 of Set 12 | osterburg
# Processing Record 48 of Set 12 | ust-ordynskiy
# Processing Record 49 of Set 12 | caala
# Processing Record 50 of Set 12 | koplik
# Processing Record 1 of Set 13 | havelock
# Processing Record 2 of Set 13 | pochutla
# Processing Record 3 of Set 13 | buraydah
# Processing Record 4 of Set 13 | constitucion
# Processing Record 5 of Set 13 | san rafael
# Processing Record 6 of Set 13 | jieshi
# Processing Record 7 of Set 13 | point fortin
# Processing Record 8 of Set 13 | garowe
# Processing Record 9 of Set 13 | bacuit
# City not found. Skipping...
# Processing Record 10 of Set 13 | puerto del rosario
# Processing Record 11 of Set 13 | lufilufi
# Processing Record 12 of Set 13 | pustoshka
# Processing Record 13 of Set 13 | bageshwar
# Processing Record 14 of Set 13 | selcuk
# Processing Record 15 of Set 13 | grand baie
# Processing Record 16 of Set 13 | igarape-miri
# City not found. Skipping...
# Processing Record 17 of Set 13 | bacolod
# Processing Record 18 of Set 13 | winnemucca
# Processing Record 19 of Set 13 | smithers
# Processing Record 20 of Set 13 | cagliari
# Processing Record 21 of Set 13 | fayaoue
# Processing Record 22 of Set 13 | biltine
# Processing Record 23 of Set 13 | mukhen
# Processing Record 24 of Set 13 | kendari
# Processing Record 25 of Set 13 | namatanai
# Processing Record 26 of Set 13 | alyangula
# Processing Record 27 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 28 of Set 13 | guerrero negro
# Processing Record 29 of Set 13 | parabel
# Processing Record 30 of Set 13 | khani
# Processing Record 31 of Set 13 | ostrovnoy
# Processing Record 32 of Set 13 | atikokan
# Processing Record 33 of Set 13 | jiexiu
# Processing Record 34 of Set 13 | ihtiman
# Processing Record 35 of Set 13 | oyotun
# Processing Record 36 of Set 13 | pouembout
# Processing Record 37 of Set 13 | birjand
# Processing Record 38 of Set 13 | xinan
# Processing Record 39 of Set 13 | kanakapura
# Processing Record 40 of Set 13 | danjiangkou
# Processing Record 41 of Set 13 | iwanai
# Processing Record 42 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 43 of Set 13 | pacific grove
# Processing Record 44 of Set 13 | ignacio de la llave
# Processing Record 45 of Set 13 | diego de almagro
# Processing Record 46 of Set 13 | andra
# Processing Record 47 of Set 13 | nizwa
# Processing Record 48 of Set 13 | shingu
# Processing Record 49 of Set 13 | atambua
# Processing Record 50 of Set 13 | mount isa
# Processing Record 1 of Set 14 | doctor arroyo
# Processing Record 2 of Set 14 | cooma
# Processing Record 3 of Set 14 | kurchum
# Processing Record 4 of Set 14 | kavaratti
# Processing Record 5 of Set 14 | aleksandrov gay
# Processing Record 6 of Set 14 | carutapera
# Processing Record 7 of Set 14 | synya
# Processing Record 8 of Set 14 | naze
# Processing Record 9 of Set 14 | codrington
# Processing Record 10 of Set 14 | swellendam
# Processing Record 11 of Set 14 | gat
# Processing Record 12 of Set 14 | saint-michel-des-saints
# Processing Record 13 of Set 14 | timizart
# Processing Record 14 of Set 14 | fort nelson
# Processing Record 15 of Set 14 | tashla
# Processing Record 16 of Set 14 | maine-soroa
# Processing Record 17 of Set 14 | pakokku
# Processing Record 18 of Set 14 | fuyang
# Processing Record 19 of Set 14 | bubaque
# Processing Record 20 of Set 14 | buqayq
# City not found. Skipping...
# Processing Record 21 of Set 14 | mali
# Processing Record 22 of Set 14 | matam
# Processing Record 23 of Set 14 | sinnamary
# Processing Record 24 of Set 14 | safaga
# Processing Record 25 of Set 14 | banepa
# Processing Record 26 of Set 14 | sola
# Processing Record 27 of Set 14 | maldonado
# Processing Record 28 of Set 14 | manuk mangkaw
# Processing Record 29 of Set 14 | weligama
# Processing Record 30 of Set 14 | devils lake
# Processing Record 31 of Set 14 | macedo de cavaleiros
# Processing Record 32 of Set 14 | barroualie
# City not found. Skipping...
# Processing Record 33 of Set 14 | majene
# Processing Record 34 of Set 14 | la primavera
# Processing Record 35 of Set 14 | doha
# Processing Record 36 of Set 14 | saint-georges
# Processing Record 37 of Set 14 | dyadkovskaya
# City not found. Skipping...
# Processing Record 38 of Set 14 | hirara
# Processing Record 39 of Set 14 | yenagoa
# Processing Record 40 of Set 14 | joshimath
# Processing Record 41 of Set 14 | poum
# Processing Record 42 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 43 of Set 14 | mayo
# Processing Record 44 of Set 14 | yumen
# Processing Record 45 of Set 14 | lasa
# Processing Record 46 of Set 14 | saltillo
# Processing Record 47 of Set 14 | marabba
# Processing Record 48 of Set 14 | rioblanco
# Processing Record 49 of Set 14 | scottsburgh
# City not found. Skipping...
# Processing Record 50 of Set 14 | rio grande
# Processing Record 1 of Set 15 | te anau
# Processing Record 2 of Set 15 | aksarka
# Processing Record 3 of Set 15 | mishelevka
# Processing Record 4 of Set 15 | siloam springs
# Processing Record 5 of Set 15 | mizdah
# Processing Record 6 of Set 15 | berbera
# Processing Record 7 of Set 15 | cedar rapids
# Processing Record 8 of Set 15 | wundanyi
# Processing Record 9 of Set 15 | korla
# Processing Record 10 of Set 15 | port augusta
# Processing Record 11 of Set 15 | kilrush
# Processing Record 12 of Set 15 | trussville
# Processing Record 13 of Set 15 | lar
# Processing Record 14 of Set 15 | yining
# Processing Record 15 of Set 15 | gao
# Processing Record 16 of Set 15 | mounana
# Processing Record 17 of Set 15 | mount darwin
# Processing Record 18 of Set 15 | samut prakan
# Processing Record 19 of Set 15 | marsala
# Processing Record 20 of Set 15 | sant julia de loria
# Processing Record 21 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 22 of Set 15 | sri aman
# Processing Record 23 of Set 15 | gornopravdinsk
# Processing Record 24 of Set 15 | killybegs
# Processing Record 25 of Set 15 | the valley
# Processing Record 26 of Set 15 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 15 | santa isabel
# Processing Record 28 of Set 15 | kushchevskaya
# Processing Record 29 of Set 15 | general roca
# Processing Record 30 of Set 15 | raudeberg
# Processing Record 31 of Set 15 | camp verde
# Processing Record 32 of Set 15 | allapalli
# Processing Record 33 of Set 15 | patos de minas
# Processing Record 34 of Set 15 | areosa
# Processing Record 35 of Set 15 | glenwood springs
# Processing Record 36 of Set 15 | perth
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0         Mataura      NZ  2022-06-23 13:09:53 -46.1927  168.8643     33.48
# 1     Alekseyevsk      RU  2022-06-23 13:09:54  57.8406  108.3492     55.18
# 2            Hilo      US  2022-06-23 13:06:59  19.7297 -155.0900     71.28
# 3          Dikson      RU  2022-06-23 13:09:54  73.5069   80.5464     43.50
# 4        Saldanha      ZA  2022-06-23 13:09:55 -33.0117   17.9442     55.54
# 5  Cabo San Lucas      MX  2022-06-23 13:09:19  22.8909 -109.9124     81.61
# 6           Bluff      NZ  2022-06-23 13:09:55 -46.6000  168.3333     33.80
# 7         Rikitea      PF  2022-06-23 13:09:56 -23.1203 -134.9692     75.22
# 8       Tilichiki      RU  2022-06-23 13:09:56  60.4667  166.1000     44.26
# 9         Kahului      US  2022-06-23 13:09:57  20.8947 -156.4700     75.22
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        81           3        3.69           clear sky
# 1        95          93        2.48          light rain
# 2        91         100        4.61          light rain
# 3        74         100       20.47     overcast clouds
# 4        88         100       25.41       moderate rain
# 5        82          76        2.86       broken clouds
# 6        78          87       12.08     overcast clouds
# 7        65          79       15.84       broken clouds
# 8        94          98        3.47     overcast clouds
# 9        77         100        9.22     overcast clouds

# %%
# Create CSV file of DF
csv_weather_file = "weatherpy_database.csv"
# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
